# %%
import numpy as np
import pandas as pd
import plotly.offline as pyo
import plotly.graph_objects as go
import plotly.express as px

# %%
match = pd.read_csv('/content/drive/MyDrive/Data_set_local/matches.csv')
delivery = pd.read_csv('/content/drive/MyDrive/Data_set_local/deliveries.csv')

# %%
ipl = delivery.merge(match , left_on='match_id',right_on ='id')
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  result  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...  normal
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
ipl.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3'],
#       dtype='object')

# %%
# scatter plots
#top 50 batsman
top_50 = ipl.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(50).index.tolist()
new_ipl = ipl[ipl['batsman'].isin(top_50)]

# %%
runs  = new_ipl.groupby('batsman')['batsman_runs'].sum()
ball = new_ipl.groupby('batsman')['batsman_runs'].count()

# %%
sr = (runs /ball) *100
sr = sr.reset_index()

# %%
sr = sr.rename(columns={'batsman_runs':'str'})

# %%
runs
# Out:
# batsman
# AB de Villiers      3486
# AC Gilchrist        2069
# AJ Finch            1604
# AM Rahane           3057
# AT Rayudu           2416
# BB McCullum         2755
# BJ Hodge            1400
# CH Gayle            3651
# DA Miller           1563
# DA Warner           4014
# DJ Bravo            1262
# DJ Hussey           1322
# DPMD Jayawardene    1808
# DR Smith            2385
# F du Plessis        1295
# G Gambhir           4132
# GJ Maxwell          1229
# JH Kallis           2427
# JP Duminy           1993
# KA Pollard          2354
# KC Sangakkara       1687
# KD Karthik          2903
# KK Nair             1158
# M Vijay             2511
# MEK Hussey          1977
# MK Pandey           2223
# MK Tiwary           1648
# MS Dhoni            3560
# NV Ojha             1553
# PA Patel            2322
# R Dravid            2174
# RA Jadeja           1732
# RG Sharma           4207
# RV Uthappa          3778
# S Badrinath         1441
# S Dhawan            3561
# ...

# %%
out  =ipl[ipl['player_dismissed'].isin(top_50)]
nout =out['player_dismissed'].value_counts().sort_index()

# %%
avg = runs/nout
avg = avg.reset_index()
avg.rename(columns={0:'avg'} ,inplace =True)
avg = avg.merge(sr,on='batsman')
avg
# Out:
#              batsman        avg         str
# 0     AB de Villiers  38.307692  145.129059
# 1       AC Gilchrist  27.223684  133.054662
# 2           AJ Finch  27.186441  126.299213
# 3          AM Rahane  33.593407  117.486549
# 4          AT Rayudu  27.146067  123.014257
# 5        BB McCullum  28.112245  126.318203
# 6           BJ Hodge  33.333333  121.422376
# 7           CH Gayle  41.022472  144.194313
# 8          DA Miller  34.733333  137.709251
# 9          DA Warner  40.140000  138.318401
# 10          DJ Bravo  22.945455  122.286822
# 11         DJ Hussey  26.979592  120.072661
# 12  DPMD Jayawardene  28.250000  118.791064
# 13          DR Smith  28.392857  132.279534
# 14      F du Plessis  30.116279  124.161074
# 15         G Gambhir  31.541985  120.361200
# 16        GJ Maxwell  25.081633  157.564103
# 17         JH Kallis  28.552941  105.936272
# 18         JP Duminy  39.860000  121.970624
# 19        KA Pollard  28.707317  140.621266
# ...

# %%
#scatter plot
trace = go.Scatter(x=avg['avg'],y=avg['str'] ,
                   mode='markers' ,
                   text = avg['batsman'],
                   marker = {'color':'#00a65a','size':16})
data =[trace]
layout = go.Layout(title='AVG vs STR',
                   xaxis={'title':'Batsman Average'},
                   yaxis ={'title':'Batsman Str'})
fig = go.Figure(data=data ,layout=layout)
pyo.plot(fig , filename='avg_vs_str.html')
# Out:
# 'avg_vs_str.html'

# %%
#scatter plot
trace = go.Scatter(x=avg['avg'],y=avg['str'] ,

                   text = avg['batsman'],
                   marker = {'color':'#00a65a','size':16})
data =[trace]
layout = go.Layout(title='AVG vs STR',
                   xaxis={'title':'Batsman Average'},
                   yaxis ={'title':'Batsman Str'})
fig = go.Figure(data=data ,layout=layout)
pyo.plot(fig, filename = 'line.html')
# Out:
# 'line.html'

# %%
ipl.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3'],
#       dtype='object')

# %%
ipl1 =ipl[ipl['batsman'] == 'V Kohli']
performance = ipl.groupby('season')['batsman_runs'].sum()
performance
# Out:
# season
# 2008    16809
# 2009    15376
# 2010    17754
# 2011    19928
# 2012    21322
# 2013    21487
# 2014    17943
# 2015    17427
# 2016    17963
# 2017    17920
# Name: batsman_runs, dtype: int64

# %%
#line chart
trace =go.Scatter(x=performance.index ,y = performance.values ,
                  mode ='lines')
data = [trace]
fig = go.Figure(data=data, layout = layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ipl1 =ipl[ipl['batsman'] == 'V Kohli']
# performance = ipl.groupby('season')['batsman_runs'].sum()
# performance
ipl2 =ipl[ipl['batsman'] == 'MS Dhoni']
performance1 = ipl1.groupby('season')['batsman_runs'].sum()
performance1
# Out:
# season
# 2008    414
# 2009    332
# 2010    287
# 2011    392
# 2012    357
# 2013    461
# 2014    371
# 2015    372
# 2016    284
# 2017    290
# Name: batsman_runs, dtype: int64

# %%
#line chart
trace1 =go.Scatter(x=performance.index ,y = performance.values ,
                  mode ='lines')

trace2 =go.Scatter(x=performance1.index ,y = performance1.values ,
                  mode ='lines')
layout = go.Layout(title = 'YoY Performance')
data = [trace1 ,trace2]
fig = go.Figure(data=data, layout = layout)
pyo.plot(fig ,filename='com.html')
# Out:
# 'com.html'

# %%
#multipe line charts
def batsman_comp(*name):
    data = []
    for i in name:
        single = ipl[ipl['batsman'] == i]
        performance = single.groupby('season')['batsman_runs'].sum().reset_index()

        trace = go.Scatter(x = performance['season'] ,y =performance['batsman_runs']
                          ,mode = 'lines + markers' ,name =i)

        data.append(trace)
    layout = go.Layout(title = 'Batsman Runs Comparison',
                       xaxis = {'title':'Season'},
                       yaxis = {'title':'Runs'})


    fig = go.Figure(data = data ,layout= layout)
    pyo.plot(fig ,filename ='Year_by_year')

# %%
batsman_comp('AB de Villiers' ,'DA Warner' , 'RG Sharma' ,'MS Dhoni')
# Out:
# /usr/local/lib/python3.11/dist-packages/plotly/offline/offline.py:557: UserWarning:
#
# Your filename `Year_by_year` didn't end with .html. Adding .html to the end of your file.
